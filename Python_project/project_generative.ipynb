# %%
# %%capture
# Installo le librerie per il progetto
# %pip install langchain
# %pip install openai

# %%
# Import del progetto + inizializzazione delle API
from langchain import PromptTemplate
from langchain.llms import OpenAI
from langchain import LLMChain
import random as rd
import requests
import pprint
import os

weather_api = "f778093341baeae8bb2fb56997fffbc8"
departure_city = "Rome"

url = f"http://api.weatherstack.com/current?access_key={weather_api}&query={departure_city}"
response = requests.get(url)
weather_data = response.json()

# INSERT API KEY
os.environ["OPENAI_API_KEY"] = "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" # your api key here

llm = OpenAI(
    model_name="gpt-3.5-turbo",    # you can pick other models but this is the best speed/effectiveness tradeoff                     
    temperature=1                     # for OpenAi, see options here: https://platform.openai.com/docs/api-reference/completions/create
    )

# %%
# Generazione del testo di ADV

template = """Write a targeted very brief advertisement (1 sentence) knowing the following information about the person:
{sex}, {age} years old, who is currently feeling {mood}.
You should keep in mind that our target is a person taking a {type_of_flight} flight, (if it is international then choose a 
fashion ad, else choose a travel company), has {time_before_departure} hours left before departure, and flies with {airline_company}
so keep it in mind to target the pricing accordingly. Choose one single product that may appeal to the person from the following list: {products} knowing that the meteo in the city the person is currently in is {meteo}.
The output should exclude any personal information about the person and should adress the target personally, 
(speaking to him like a friend), and the him why he should be interested to the ad."""
prompt = PromptTemplate(template=template, input_variables=["sex", "age", "mood", "type_of_flight", "time_before_departure", "airline_company", "meteo", "products"])

llm_chain = LLMChain(
    prompt=prompt, 
    llm=llm, 
    verbose=True)

type_of_flight = ['National', 'International']
time_before_departure = [2, 3, 4, 5]
airline_companies = ["Alitalia", "American Airlines", "British Airways", "Delta Air Lines", "Emirates", "Lufthansa", "Air France", "United Airlines", "Southwest Airlines", "Ryanair", "EasyJet", "Qatar Airways", "Cathay Pacific", "Singapore Airlines", "JetBlue Airways"]
products = ["Amazon", "Walmart", "Target", "Apple", "Samsung", "Nike", "Adidas", "Coca-Cola", "PepsiCo", "Procter & Gamble", "Johnson & Johnson", "General Electric", "Nestle", "Unilever", "The Home Depot", "Costco", "IKEA", "CVS Health", "Toyota", "BMW", "Verizon Communications", "AT&T", "Boeing", "ExxonMobil", "Chevron","Google", "Microsoft", "Facebook", "Twitter", "Uber", "Airbnb", "Netflix", "Tesla", "Honda", "Mercedes-Benz", "Audi", "Pepsi", "Coca-Cola", "McDonald's", "KFC", "Subway", "Volkswagen", "Nest", "Sony", "LG", "HP", "Dell", "Intel", "AMD", "NVIDIA", "Airbnb", "Dropbox", "Spotify", "Adobe", "IBM", "Oracle", "SAP", "Cisco", "Boeing", "Lockheed Martin", "Raytheon", "General Motors", "ExxonMobil", "Chevron", "BP", "Shell", "Total SA", "GlaxoSmithKline", "Pfizer", "Novartis", "Sanofi", "Roche", "AstraZeneca""JPMorgan Chase", "Visa", "Mastercard", "American Express", "Ford Motor Company"]
moods = ['Sad', 'Happy', 'Angry', 'Excited', 'Bored']
ages = ['20', '30', '40', '50', '60']
sex = ['Male', 'Female']

for _ in range(5):
    results = llm_chain.run(sex=rd.choice(sex), age=rd.choice(ages), mood=rd.choice(moods), type_of_flight=rd.choice(type_of_flight), time_before_departure=rd.choice(time_before_departure), airline_company=rd.choice(airline_companies), meteo=weather_data, products=products)
    pprint.pprint(results)
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a targeted very brief advertisement (1 sentence) knowing the following information about the person:
# Male, 60 years old, who is currently feeling Happy.
# You should keep in mind that our target is a person taking a International flight, (if it is international then choose a
# fashion ad, else choose a travel company), has 5 hours left before departure, and flies with Alitalia
# ...
